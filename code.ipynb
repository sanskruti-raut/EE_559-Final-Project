# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv('laptop_data_train.csv')
df.head()
# Out:
#    Number Company   TypeName  Inches                    ScreenResolution  \
# 0       0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1       1   Apple  Ultrabook    13.3                            1440x900
# 2       2      HP   Notebook    15.6                   Full HD 1920x1080
# 3       3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4       4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df = pd.read_csv('laptop_data_test.csv')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Number              0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches  \
# 0       0    Asus              Gaming    17.3
# 1       1    Dell  2 in 1 Convertible    13.3
# 2       2  Lenovo           Ultrabook    14.0
# 3       3  Lenovo            Notebook    15.6
# 4       4      LG           Ultrabook    15.6
#
#                             ScreenResolution                          Cpu  \
# 0                IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz
# 1            Full HD / Touchscreen 1920x1080    Intel Core i7 7Y75 1.3GHz
# 2                IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 3                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 4  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
#
#     Ram                  Memory                      Gpu       OpSys  Weight  \
# 0  32GB  256GB SSD +  256GB SSD  Nvidia GeForce GTX 980M  Windows 10  3.58kg
# 1  16GB               256GB SSD    Intel HD Graphics 615  Windows 10  1.22kg
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB', '')
df['Weight'] = df['Weight'].str.replace('kg', '')

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches  \
# 0       0    Asus              Gaming    17.3
# 1       1    Dell  2 in 1 Convertible    13.3
# 2       2  Lenovo           Ultrabook    14.0
# 3       3  Lenovo            Notebook    15.6
# 4       4      LG           Ultrabook    15.6
#
#                             ScreenResolution                          Cpu Ram  \
# 0                IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz  32
# 1            Full HD / Touchscreen 1920x1080    Intel Core i7 7Y75 1.3GHz  16
# 2                IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8
# 3                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8
# 4  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz  16
#
#                    Memory                      Gpu       OpSys Weight  \
# 0  256GB SSD +  256GB SSD  Nvidia GeForce GTX 980M  Windows 10   3.58
# 1               256GB SSD    Intel HD Graphics 615  Windows 10   1.22
# ...

# %%
# Convert 'Ram' and 'Weight' columns to numeric
df['Ram'] = df['Ram'].astype(int)
df['Weight'] = df['Weight'].astype(float)

# %%
# Split the 'ScreenResolution' column by 'x' and expand it into separate columns
resolution_split = df['ScreenResolution'].str.split('x', expand=True)

# Extract screen resolution width and height from the split columns
df['ResolutionWidth'] = resolution_split[0].str.extract('(\d+)').astype(int)
df['ResolutionHeight'] = resolution_split[1].str.extract('(\d+)').astype(int)

# Drop the original 'ScreenResolution' column
df.drop('ScreenResolution', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches                          Cpu  \
# 0       0    Asus              Gaming    17.3  Intel Core i7 6820HK 2.7GHz
# 1       1    Dell  2 in 1 Convertible    13.3    Intel Core i7 7Y75 1.3GHz
# 2       2  Lenovo           Ultrabook    14.0   Intel Core i7 7500U 2.7GHz
# 3       3  Lenovo            Notebook    15.6   Intel Core i5 7200U 2.5GHz
# 4       4      LG           Ultrabook    15.6   Intel Core i7 7500U 2.7GHz
#
#    Ram                  Memory                      Gpu       OpSys  Weight  \
# 0   32  256GB SSD +  256GB SSD  Nvidia GeForce GTX 980M  Windows 10    3.58
# 1   16               256GB SSD    Intel HD Graphics 615  Windows 10    1.22
# 2    8     256GB Flash Storage    Intel HD Graphics 620  Windows 10    1.13
# 3    8               512GB SSD    Intel HD Graphics 620  Windows 10    1.95
# 4   16               512GB SSD    Intel HD Graphics 620  Windows 10    1.08
#
#          Price  ResolutionWidth  ResolutionHeight
# ...

# %%
# print(df['Memory'].dtype)
# Convert 'Memory' column to string
df['Memory'] = df['Memory'].astype(str)

# Extract storage capacity from 'Memory' column
df['Memory'] = df['Memory'].str.extract('(\d+)', expand=False)

# Convert 'Memory' column to numeric
df['Memory'] = df['Memory'].astype(float)

# Continue with the remaining preprocessing steps

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches                          Cpu  \
# 0       0    Asus              Gaming    17.3  Intel Core i7 6820HK 2.7GHz
# 1       1    Dell  2 in 1 Convertible    13.3    Intel Core i7 7Y75 1.3GHz
# 2       2  Lenovo           Ultrabook    14.0   Intel Core i7 7500U 2.7GHz
# 3       3  Lenovo            Notebook    15.6   Intel Core i5 7200U 2.5GHz
# 4       4      LG           Ultrabook    15.6   Intel Core i7 7500U 2.7GHz
#
#    Ram  Memory                      Gpu       OpSys  Weight        Price  \
# 0   32   256.0  Nvidia GeForce GTX 980M  Windows 10    3.58   68145.1200
# 1   16   256.0    Intel HD Graphics 615  Windows 10    1.22   87858.7200
# 2    8   256.0    Intel HD Graphics 620  Windows 10    1.13  109170.7200
# 3    8   512.0    Intel HD Graphics 620  Windows 10    1.95  104588.1072
# 4   16   512.0    Intel HD Graphics 620  Windows 10    1.08  111834.7200
#
#    ResolutionWidth  ResolutionHeight
# 0             1920              1080
# ...

# %%
# df['Gpu'] = df['Gpu'].astype(str)
# df['GpuMemory'] = df['Gpu'].str.extract('(\d+)', expand=False)
# df['GpuMemory'] = df['GpuMemory'].astype(float)

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches                          Cpu  \
# 0       0    Asus              Gaming    17.3  Intel Core i7 6820HK 2.7GHz
# 1       1    Dell  2 in 1 Convertible    13.3    Intel Core i7 7Y75 1.3GHz
# 2       2  Lenovo           Ultrabook    14.0   Intel Core i7 7500U 2.7GHz
# 3       3  Lenovo            Notebook    15.6   Intel Core i5 7200U 2.5GHz
# 4       4      LG           Ultrabook    15.6   Intel Core i7 7500U 2.7GHz
#
#    Ram  Memory                      Gpu       OpSys  Weight        Price  \
# 0   32   256.0  Nvidia GeForce GTX 980M  Windows 10    3.58   68145.1200
# 1   16   256.0    Intel HD Graphics 615  Windows 10    1.22   87858.7200
# 2    8   256.0    Intel HD Graphics 620  Windows 10    1.13  109170.7200
# 3    8   512.0    Intel HD Graphics 620  Windows 10    1.95  104588.1072
# 4   16   512.0    Intel HD Graphics 620  Windows 10    1.08  111834.7200
#
#    ResolutionWidth  ResolutionHeight
# 0             1920              1080
# ...

# %%
# df['Cpu'] = df['Cpu'].str.extract(r'(\d+\.\d+|\d+)').astype(float)

# %%
df.head()
# Out:
#    Number Company            TypeName  Inches                          Cpu  \
# 0       0    Asus              Gaming    17.3  Intel Core i7 6820HK 2.7GHz
# 1       1    Dell  2 in 1 Convertible    13.3    Intel Core i7 7Y75 1.3GHz
# 2       2  Lenovo           Ultrabook    14.0   Intel Core i7 7500U 2.7GHz
# 3       3  Lenovo            Notebook    15.6   Intel Core i5 7200U 2.5GHz
# 4       4      LG           Ultrabook    15.6   Intel Core i7 7500U 2.7GHz
#
#    Ram  Memory                      Gpu       OpSys  Weight        Price  \
# 0   32   256.0  Nvidia GeForce GTX 980M  Windows 10    3.58   68145.1200
# 1   16   256.0    Intel HD Graphics 615  Windows 10    1.22   87858.7200
# 2    8   256.0    Intel HD Graphics 620  Windows 10    1.13  109170.7200
# 3    8   512.0    Intel HD Graphics 620  Windows 10    1.95  104588.1072
# 4   16   512.0    Intel HD Graphics 620  Windows 10    1.08  111834.7200
#
#    ResolutionWidth  ResolutionHeight
# 0             1920              1080
# ...

# %%
# Perform one-hot encoding for categorical variables
df = pd.get_dummies(df, columns=['Company', 'TypeName', 'Cpu', 'Gpu', 'OpSys'])

# %%
# # Separate features (X) and target variable (y)
# X = df.drop('Price', axis=1)
# y = df['Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer

# %%
X_train = df.drop(['Price', 'Number'], axis=1)  # Drop 'Price' which is the target and 'Number' which is just an index
y_train = df['Price']

# %%
X_train.head()
# Out:
#    Inches  Ram  Memory  Weight  ResolutionWidth  ResolutionHeight  \
# 0    17.3   32   256.0    3.58             1920              1080
# 1    13.3   16   256.0    1.22             1920              1080
# 2    14.0    8   256.0    1.13             1920              1080
# 3    15.6    8   512.0    1.95             1920              1080
# 4    15.6   16   512.0    1.08             1920              1080
#
#    Company_Acer  Company_Apple  Company_Asus  Company_Dell  ...  \
# 0         False          False          True         False  ...
# 1         False          False         False          True  ...
# 2         False          False         False         False  ...
# 3         False          False         False         False  ...
# 4         False          False         False         False  ...
#
#    Gpu_Nvidia Quadro M1000M  Gpu_Nvidia Quadro M3000M  \
# 0                     False                     False
# 1                     False                     False
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create a Linear Regression model
linear_reg_model = LinearRegression()

# Fit the model to the training data
linear_reg_model.fit(X_train, y_train)

# Predict on the training data
y_train_pred = linear_reg_model.predict(X_train)

# Evaluate the model

train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)
train_mse = mean_squared_error(y_train, y_train_pred)

print("Training MSE:", train_mse)
print("Training MAE:", train_mae)
print("Training R-squared:", train_r2)
# Out:
# Training MSE: 170803041.4552863
# Training MAE: 8191.854068485697
# Training R-squared: 0.8669844895533965

# %%
from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the numerical features
X_train_scaled = scaler.fit_transform(X_train)

# %%
print("Mean of scaled features:", X_train_scaled.mean(axis=0))
print("Standard deviation of scaled features:", X_train_scaled.std(axis=0))
# Out:
# Mean of scaled features: [ 2.20939905e-16 -1.14888751e-16  4.41879811e-17  3.53503849e-16
#  -1.54657934e-17  1.67914328e-16 -1.10469953e-17 -3.53503849e-17
#   1.76751924e-17 -1.76751924e-17  8.83759622e-18 -5.30255773e-17
#   1.32563943e-17  1.14888751e-16 -2.20939905e-17  1.76751924e-17
#   0.00000000e+00 -1.76751924e-17  1.76751924e-17 -3.09315868e-17
#   4.41879811e-18 -1.65704929e-17 -3.09315868e-17  2.20939905e-17
#  -1.32563943e-17 -8.83759622e-18  1.32563943e-17  1.76751924e-17
#  -8.83759622e-18  8.83759622e-18 -1.76751924e-17 -1.76751924e-17
#  -8.83759622e-18 -1.76751924e-17 -1.32563943e-17  1.76751924e-17
#  -4.19785820e-17 -4.41879811e-17 -8.83759622e-18 -7.07007697e-17
#  -2.20939905e-17  8.83759622e-18  1.10469953e-17 -1.76751924e-17
#  -1.76751924e-17 -1.76751924e-17 -1.76751924e-17  0.00000000e+00
#  -1.32563943e-17  5.30255773e-17  4.86067792e-17  4.86067792e-17
#  -2.43033896e-17 -8.83759622e-18 -6.18631735e-17 -3.31409858e-17
# ...

# %%
# Create a Linear Regression model
linear_reg_model = LinearRegression()

# Fit the model to the scaled training data
linear_reg_model.fit(X_train_scaled, y_train)

# Predict on the scaled training data
y_train_pred = linear_reg_model.predict(X_train_scaled)

# Evaluate the model on the training set
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

print("Training MSE:", train_mse)
print("Training MAE:", train_mae)
print("Training R-squared:", train_r2)
# Out:
# Training MSE: 205616863.34044817
# Training MAE: 9925.446525412242
# Training R-squared: 0.8398726872740194

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define the neural network model
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(1)  # Output layer with a single neuron (for regression)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error', 'mse'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32)

# Evaluate the model
evaluation_results = model.evaluate(X_test_scaled, y_test)
print("Test Loss:", evaluation_results[0])
print("Test MAE:", evaluation_results[1])
print("Test MSE:", evaluation_results[2])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Define the neural network model
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),  # Adding dropout for regularization
    layers.Dense(1)  # Output layer with a single neuron (for regression)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error', 'mse'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, verbose=1)

# Evaluate the model on training data
y_train_pred = model.predict(X_train_scaled)
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

print("Training MSE:", train_mse)
print("Training MAE:", train_mae)
print("Training R-squared:", train_r2)
# Out:
# Epoch 1/100
# /Users/sanskrutiraut/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - loss: 5040944640.0000 - mean_absolute_error: 61888.4023 - mse: 5040944640.0000
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 4830222336.0000 - mean_absolute_error: 59845.2148 - mse: 4830222336.0000
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 5162337792.0000 - mean_absolute_error: 62000.1445 - mse: 5162337792.0000
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 5170984960.0000 - mean_absolute_error: 61943.1250 - mse: 5170984960.0000
# Epoch 5/100
# ...
